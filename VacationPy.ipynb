# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
#%pip install cartopy
#%pip install pyproj
#%pip install geoviews

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       Grytviken -54.2811  -36.5092     41.88        73          34
# 1        1        Tazovsky  67.4667   78.7000    -12.37        97          56
# 2        2       Carnarvon -24.8667  113.6333     72.82        85           0
# 3        3          Mahdia  35.5047   11.0622     49.95        60           2
# 4        4  Ribeira Grande  38.5167  -28.7000     61.20        77          40
#
#    Wind Speed Country        Date
# 0        3.87      GS  1704662188
# 1        7.27      RU  1704662189
# 2       14.03      AU  1704662189
# 3       17.16      TN  1704662189
# 4       18.41      PT  1704662189

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    scale = 1,
    frame_width = 700,
    frame_height = 500,
    color = "City",
    alpha = 0.5,
)
# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
Temp_city_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 80) & (city_data_df["Max Temp"] > 70)]
Temp_city_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 2          2          Carnarvon -24.8667  113.6333     72.82        85
# 5          5          Adamstown -25.0660 -130.1015     73.42        72
# 31        31        Minas Novas -17.2186  -42.5903     72.82        95
# 32        32               Sarh   9.1429   18.3923     78.31        15
# 38        38         Port Sudan  19.6175   37.2164     76.77        78
# ..       ...                ...      ...       ...       ...       ...
# 557      557          Mount Isa -20.7333  139.5000     74.97        94
# 563      563  Kizhake Chālakudi  10.3000   76.3500     76.96        94
# 565      565            Janaúba -15.8025  -43.3089     79.12        75
# 567      567         Andergrove -21.0833  149.1833     78.64        80
# 569      569            Toliara -23.3500   43.6667     79.57        85
#
#      Cloudiness  Wind Speed Country        Date
# 2             0       14.03      AU  1704662189
# 5           100       15.50      PN  1704662189
# 31          100        2.82      BR  1704662193
# 32           52        4.05      TD  1704662193
# 38           28        9.22      SD  1704662194
# ..          ...         ...     ...         ...
# 557          91        5.75      AU  1704662303
# 563          75        2.30      IN  1704662303
# 565         100        4.32      BR  1704662254
# 567         100        7.25      AU  1704662304
# 569           6        3.76      MG  1704662304
#
# [125 rows x 10 columns]

# %%
# Drop any rows with null values
Temp_city_df= Temp_city_df.dropna()

Temp_city_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 2          2          Carnarvon -24.8667  113.6333     72.82        85
# 5          5          Adamstown -25.0660 -130.1015     73.42        72
# 31        31        Minas Novas -17.2186  -42.5903     72.82        95
# 32        32               Sarh   9.1429   18.3923     78.31        15
# 38        38         Port Sudan  19.6175   37.2164     76.77        78
# ..       ...                ...      ...       ...       ...       ...
# 557      557          Mount Isa -20.7333  139.5000     74.97        94
# 563      563  Kizhake Chālakudi  10.3000   76.3500     76.96        94
# 565      565            Janaúba -15.8025  -43.3089     79.12        75
# 567      567         Andergrove -21.0833  149.1833     78.64        80
# 569      569            Toliara -23.3500   43.6667     79.57        85
#
#      Cloudiness  Wind Speed Country        Date
# 2             0       14.03      AU  1704662189
# 5           100       15.50      PN  1704662189
# 31          100        2.82      BR  1704662193
# 32           52        4.05      TD  1704662193
# 38           28        9.22      SD  1704662194
# ..          ...         ...     ...         ...
# 557          91        5.75      AU  1704662303
# 563          75        2.30      IN  1704662303
# 565         100        4.32      BR  1704662254
# 567         100        7.25      AU  1704662304
# 569           6        3.76      MG  1704662304
#
# [122 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

Hotel_df=Temp_city_df[['City', 'Country', 'Lat','Lng','Humidity']].copy()


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
Hotel_df['Hotel Name']=" "
Hotel_df
# Display sample data
# YOUR CODE HERE
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 2            Carnarvon      AU -24.8667  113.6333        85
# 5            Adamstown      PN -25.0660 -130.1015        72
# 31         Minas Novas      BR -17.2186  -42.5903        95
# 32                Sarh      TD   9.1429   18.3923        15
# 38          Port Sudan      SD  19.6175   37.2164        78
# ..                 ...     ...      ...       ...       ...        ...
# 557          Mount Isa      AU -20.7333  139.5000        94
# 563  Kizhake Chālakudi      IN  10.3000   76.3500        94
# 565            Janaúba      BR -15.8025  -43.3089        75
# 567         Andergrove      AU -21.0833  149.1833        80
# 569            Toliara      MG -23.3500   43.6667        85
#
# [122 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in Hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude=row['Lat']
    longitude=row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        Hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        Hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{Hotel_df.loc[index, 'City']} - nearest hotel: {Hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
Hotel_df
# Out:
# Starting hotel search
# Carnarvon - nearest hotel: No hotel found
# Adamstown - nearest hotel: No hotel found
# Minas Novas - nearest hotel: Grande Hotel
# Sarh - nearest hotel: فندق سفاري
# Port Sudan - nearest hotel: Ranya Hotel
# Odiongan - nearest hotel: Haliwood Inn
# Wailua Homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# Ambovombe - nearest hotel: La source
# Nabire - nearest hotel: Hotel Anggrek
# Bamboo Flat - nearest hotel: Hotel Megapode Nest
# Niafunké - nearest hotel: No hotel found
# George Town - nearest hotel: Page 63 hostel
# Quatre Cocos - nearest hotel: Horisun
# Buta - nearest hotel: Hôtel Rubi
# Campos Belos - nearest hotel: No hotel found
# Tsiombe - nearest hotel: No hotel found
# Tombodu - nearest hotel: No hotel found
# Kinkala - nearest hotel: hotel
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Hawaiian Paradise Park - nearest hotel: No hotel found
# Forster - nearest hotel: No hotel found
# Belmonte - nearest hotel: No hotel found
# Trincomalee - nearest hotel: Summer set inn
# Hilo - nearest hotel: Dolphin Bay Hotel
# Extrema - nearest hotel: Hotel San Marco
# Chabahar - nearest hotel: هتل سپیده
# Nakasongola - nearest hotel: No hotel found
# Port Saint John's - nearest hotel: Outback Inn
# Wellington - nearest hotel: Travelodge
# Sur - nearest hotel: Sur Hotel
# Saipan - nearest hotel: Chalan Kanoa Beach Hotel
# Kerikeri - nearest hotel: Avalon Resort
# Sarikei - nearest hotel: No hotel found
# Christchurch - nearest hotel: Ibis Hotel Christchurch
# Charters Towers - nearest hotel: No hotel found
# Kalianget - nearest hotel: No hotel found
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Atafu Village - nearest hotel: No hotel found
# Richards Bay - nearest hotel: SUN1 Richards Bay
# Kuraymah - nearest hotel: Hotel al Nasser
# Gurupi - nearest hotel: Via Norte
# Nova Sintra - nearest hotel: Residência Ka Dencho
# Katabu - nearest hotel: No hotel found
# Pontianak - nearest hotel: Golden Tulip Hotel
# Thames - nearest hotel: Kopu Station Hotel
# Martapura - nearest hotel: Q-Hotel Grand Dafam
# Kolokani - nearest hotel: Hôtel kolokani
# Rawai - nearest hotel: Rawai Boutique Resort
# Nambucca Heads - nearest hotel: Star Hotel
# Lihue - nearest hotel: Kauai Palms
# Nova Viçosa - nearest hotel: Pousada Pontal da Barra
# Port Shepstone - nearest hotel: The Spot Backpackers'
# Kidal - nearest hotel: No hotel found
# Mossamedes - nearest hotel: Hotel Chik Chik Namibe
# Bulolo - nearest hotel: No hotel found
# Sinabang - nearest hotel: No hotel found
# Tôlanaro - nearest hotel: Hôtel Mahavokey
# Marsa Alam - nearest hotel: Blue House Hotel
# Trujillo - nearest hotel: Hostal Ayacucho
# Lae - nearest hotel: Huon Gulf Hotel
# Swan Hill - nearest hotel: Murray Downs Golf Resort
# Lodja - nearest hotel: No hotel found
# Tobelo - nearest hotel: JJ Guesthouse
# Taro - nearest hotel: Padma Resort Ubud
# Ed Damer - nearest hotel: No hotel found
# Katagum - nearest hotel: No hotel found
# Antofagasta - nearest hotel: Hotel Colón
# Nosy Varika - nearest hotel: No hotel found
# Port Victoria - nearest hotel: No hotel found
# Alice Springs - nearest hotel: Aurora Alice Springs
# Maluso - nearest hotel: No hotel found
# Ormara - nearest hotel: No hotel found
# Tadine - nearest hotel: Hôtel Nengoné
# Conceição da Barra - nearest hotel: Porto Marlin Hotel
# Mutuáli - nearest hotel: No hotel found
# San Patricio - nearest hotel: No hotel found
# Haiku-Pauwela - nearest hotel: Inn At Mama's Fish House
# Carutapera - nearest hotel: No hotel found
# Chokwé - nearest hotel: Limpopo Hotel
# Am Timan - nearest hotel: Nimla
# Port Macquarie - nearest hotel: The Observatory
# Hadibu - nearest hotel: No hotel found
# Souillac - nearest hotel: Hotel SkylineInn
# Pisco - nearest hotel: La Portada
# Santa Terezinha - nearest hotel: Pousada Santa Terezinha
# Tutóia - nearest hotel: Pousada San Vicente
# Kokopo - nearest hotel: Hotel Kokopo
# Saint-Joseph - nearest hotel: PALM Hotel & Spa
# San Fernando - nearest hotel: Pampanga Lodge and Restaurant
# Telimele - nearest hotel: No hotel found
# Flying Fish Cove - nearest hotel: Christmas Island Lodge
# Bengkulu - nearest hotel: Dena Hotel
# Boyolangu - nearest hotel: Crown Victoria
# Saint-Philippe - nearest hotel: Le Baril
# Noosa - nearest hotel: Costa Nova Apartments
# Bankim - nearest hotel: No hotel found
# Moussoro - nearest hotel: No hotel found
# Castro - nearest hotel: Hotel Central Palace
# Vung Tau - nearest hotel: No hotel found
# Maragogi - nearest hotel: Pousada Mariluz
# Mermoz Boabab - nearest hotel: La maison blanche
# Hobyo - nearest hotel: Iftin Hotel Hobyo
# Duong Dong - nearest hotel: Kim Hông Ngoc
# Mtama - nearest hotel: No hotel found
# Pamekasan - nearest hotel: Hotel Ramayana
# Saint-Pierre - nearest hotel: Tropic Hotel
# Sorong - nearest hotel: Hotel Membramo Marina
# Mandapam - nearest hotel: GOWRI MESS
# Kalmunai - nearest hotel: Saji new food
# City of Taguig - nearest hotel: Generosa's Garden
# Francistown - nearest hotel: City Inn
# Kérouané - nearest hotel: No hotel found
# Coruripe - nearest hotel: No hotel found
# Darwin - nearest hotel: Mantra Pantanas Darwin
# Victoria Point - nearest hotel: Seminara Appartments
# Villa Gesell - nearest hotel: Hotel El Faro
# Karaton - nearest hotel: Orange Syariah
# Mount Isa - nearest hotel: Ibis Styles
# Kizhake Chālakudi - nearest hotel: gokulam

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

map_plot_1 = Hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    scale = 1,
    frame_width = 700,
    frame_height = 500,
    color = "City",
    alpha = 0.5,
    hover_cols = ["Hotel Name", "Country"]
)

map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
